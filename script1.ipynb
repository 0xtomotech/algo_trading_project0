# %% [markdown]
# Script 1

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Get Data

# %%
Apple = yf.download('AAPL', start='2014-01-01', end='2024-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-01-02   19.845715   19.893929   19.715000   19.754642   17.296654
# 2014-01-03   19.745001   19.775000   19.301071   19.320715   16.916721
# 2014-01-06   19.194643   19.528570   19.057142   19.426071   17.008972
# 2014-01-07   19.440001   19.498571   19.211430   19.287144   16.887327
# 2014-01-08   19.243214   19.484285   19.238930   19.409286   16.994276
# ...                ...         ...         ...         ...         ...
# 2023-12-22  195.179993  195.410004  192.970001  193.600006  193.353287
# 2023-12-26  193.610001  193.889999  192.830002  193.050003  192.803986
# 2023-12-27  192.490005  193.500000  191.089996  193.149994  192.903839
# 2023-12-28  194.139999  194.660004  193.169998  193.580002  193.333298
# 2023-12-29  193.899994  194.399994  191.729996  192.529999  192.284637
#
#                Volume
# Date
# 2014-01-02  234684800
# 2014-01-03  392467600
# 2014-01-06  412610800
# ...

# %%
ticker=["SPY", "AAPL", "TSLA"]

# %%
stocks = yf.download(ticker, start='2014-01-01', end='2024-01-01')
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks
# Out:
# Price        Adj Close                               Close              \
# Ticker            AAPL         SPY        TSLA        AAPL         SPY
# Date
# 2014-01-02   17.296654  152.196228   10.006667   19.754642  182.919998
# 2014-01-03   16.916721  152.171295    9.970667   19.320715  182.889999
# 2014-01-06   17.008972  151.730286    9.800000   19.426071  182.360001
# 2014-01-07   16.887327  152.662216    9.957333   19.287144  183.479996
# 2014-01-08   16.994276  152.695480   10.085333   19.409286  183.520004
# ...                ...         ...         ...         ...         ...
# 2023-12-22  193.353287  472.182892  252.539993  193.600006  473.649994
# 2023-12-26  192.803986  474.176697  256.609985  193.050003  475.649994
# 2023-12-27  192.903839  475.034058  261.440002  193.149994  476.510010
# 2023-12-28  193.333298  475.213501  253.179993  193.580002  476.690002
# 2023-12-29  192.284637  473.837769  248.479996  192.529999  475.309998
#
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2516 entries, 2014-01-02 to 2023-12-29
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2516 non-null   float64
#  1   (Adj Close, SPY)   2516 non-null   float64
#  2   (Adj Close, TSLA)  2516 non-null   float64
#  3   (Close, AAPL)      2516 non-null   float64
#  4   (Close, SPY)       2516 non-null   float64
#  5   (Close, TSLA)      2516 non-null   float64
#  6   (High, AAPL)       2516 non-null   float64
#  7   (High, SPY)        2516 non-null   float64
#  8   (High, TSLA)       2516 non-null   float64
#  9   (Low, AAPL)        2516 non-null   float64
#  10  (Low, SPY)         2516 non-null   float64
#  11  (Low, TSLA)        2516 non-null   float64
#  12  (Open, AAPL)       2516 non-null   float64
#  13  (Open, SPY)        2516 non-null   float64
#  14  (Open, TSLA)       2516 non-null   float64
# ...

# %%
stocks.to_csv("script1_stocks.csv")

# %%
stocks = pd.read_csv("script1_stocks.csv")
stocks
# Out:
#            Price           Adj Close         Adj Close.1         Adj Close.2  \
# 0         Ticker                AAPL                 SPY                TSLA
# 1           Date                 NaN                 NaN                 NaN
# 2     2014-01-02  17.296653747558594  152.19622802734375  10.006667137145996
# 3     2014-01-03   16.91672134399414  152.17129516601562   9.970666885375977
# 4     2014-01-06   17.00897216796875  151.73028564453125   9.800000190734863
# ...          ...                 ...                 ...                 ...
# 2513  2023-12-22  193.35328674316406   472.1828918457031   252.5399932861328
# 2514  2023-12-26  192.80398559570312  474.17669677734375   256.6099853515625
# 2515  2023-12-27  192.90383911132812   475.0340576171875  261.44000244140625
# 2516  2023-12-28   193.3332977294922   475.2135009765625  253.17999267578125
# 2517  2023-12-29  192.28463745117188   473.8377685546875  248.47999572753906
#
# ...

# %%
stocks = pd.read_csv("script1_stocks.csv", header=[0, 1], index_col=0, parse_dates=True)
stocks
# Out:
# Price        Adj Close                               Close              \
# Ticker            AAPL         SPY        TSLA        AAPL         SPY
# Date
# 2014-01-02   17.296654  152.196228   10.006667   19.754642  182.919998
# 2014-01-03   16.916721  152.171295    9.970667   19.320715  182.889999
# 2014-01-06   17.008972  151.730286    9.800000   19.426071  182.360001
# 2014-01-07   16.887327  152.662216    9.957333   19.287144  183.479996
# 2014-01-08   16.994276  152.695480   10.085333   19.409286  183.520004
# ...                ...         ...         ...         ...         ...
# 2023-12-22  193.353287  472.182892  252.539993  193.600006  473.649994
# 2023-12-26  192.803986  474.176697  256.609985  193.050003  475.649994
# 2023-12-27  192.903839  475.034058  261.440002  193.149994  476.510010
# 2023-12-28  193.333298  475.213501  253.179993  193.580002  476.690002
# 2023-12-29  192.284637  473.837769  248.479996  192.529999  475.309998
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',  'SPY'),
#             ('Adj Close', 'TSLA'),
#             (    'Close', 'AAPL'),
#             (    'Close',  'SPY'),
#             (    'Close', 'TSLA'),
#             (     'High', 'AAPL'),
#             (     'High',  'SPY'),
#             (     'High', 'TSLA'),
#             (      'Low', 'AAPL'),
#             (      'Low',  'SPY'),
#             (      'Low', 'TSLA'),
#             (     'Open', 'AAPL'),
#             (     'Open',  'SPY'),
#             (     'Open', 'TSLA'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',  'SPY'),
#             (   'Volume', 'TSLA')],
#            names=['Price', 'Ticker'])

# %%
# Convert multi-index to a tuple
stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),  ('Adj Close', 'SPY'), ('Adj Close', 'TSLA'),
#            ('Close', 'AAPL'),      ('Close', 'SPY'),     ('Close', 'TSLA'),
#             ('High', 'AAPL'),       ('High', 'SPY'),      ('High', 'TSLA'),
#              ('Low', 'AAPL'),        ('Low', 'SPY'),       ('Low', 'TSLA'),
#             ('Open', 'AAPL'),       ('Open', 'SPY'),      ('Open', 'TSLA'),
#           ('Volume', 'AAPL'),     ('Volume', 'SPY'),    ('Volume', 'TSLA')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, SPY)  (Adj Close, TSLA)  \
# Date
# 2014-01-02          17.296654        152.196228          10.006667
# 2014-01-03          16.916721        152.171295           9.970667
# 2014-01-06          17.008972        151.730286           9.800000
# 2014-01-07          16.887327        152.662216           9.957333
# 2014-01-08          16.994276        152.695480          10.085333
# ...                       ...               ...                ...
# 2023-12-22         193.353287        472.182892         252.539993
# 2023-12-26         192.803986        474.176697         256.609985
# 2023-12-27         192.903839        475.034058         261.440002
# 2023-12-28         193.333298        475.213501         253.179993
# 2023-12-29         192.284637        473.837769         248.479996
#
#             (Close, AAPL)  (Close, SPY)  (Close, TSLA)  (High, AAPL)  \
# Date
# 2014-01-02      19.754642    182.919998      10.006667     19.893929
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',  'SPY'),
#             ('Adj Close', 'TSLA'),
#             (    'Close', 'AAPL'),
#             (    'Close',  'SPY'),
#             (    'Close', 'TSLA'),
#             (     'High', 'AAPL'),
#             (     'High',  'SPY'),
#             (     'High', 'TSLA'),
#             (      'Low', 'AAPL'),
#             (      'Low',  'SPY'),
#             (      'Low', 'TSLA'),
#             (     'Open', 'AAPL'),
#             (     'Open',  'SPY'),
#             (     'Open', 'TSLA'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',  'SPY'),
#             (   'Volume', 'TSLA')],
#            )

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL          SPY         TSLA         AAPL          SPY
# count  2516.000000  2516.000000  2516.000000  2516.000000  2516.000000
# mean     75.888208   278.875778    94.072491    77.920721   300.164014
# std      56.658817    96.878283   108.500301    56.226768    89.724506
# min      15.628377   144.915939     9.289333    17.849285   174.169998
# 25%      27.197016   183.617584    15.814167    29.803750   212.474998
# 50%      46.033028   255.790596    21.877666    48.107500   279.309998
# 75%     132.483547   377.521011   200.049999   134.562496   389.725006
# max     197.857529   475.213501   409.970001   198.110001   477.709991
#
#                            High                                    Low  \
#               TSLA         AAPL          SPY         TSLA         AAPL
# count  2516.000000  2516.000000  2516.000000  2516.000000  2516.000000
# ...

# %%
close = stocks.loc[:, "Close"].copy()
close
# Out:
#                   AAPL         SPY        TSLA
# Date
# 2014-01-02   19.754642  182.919998   10.006667
# 2014-01-03   19.320715  182.889999    9.970667
# 2014-01-06   19.426071  182.360001    9.800000
# 2014-01-07   19.287144  183.479996    9.957333
# 2014-01-08   19.409286  183.520004   10.085333
# ...                ...         ...         ...
# 2023-12-22  193.600006  473.649994  252.539993
# 2023-12-26  193.050003  475.649994  256.609985
# 2023-12-27  193.149994  476.510010  261.440002
# 2023-12-28  193.580002  476.690002  253.179993
# 2023-12-29  192.529999  475.309998  248.479996
#
# [2516 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

print(plt.style.available)

plt.style.use("seaborn-v0_8-darkgrid")
close.plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize=13)
plt.show()
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# Normalise the data
close.AAPL
# Out:
# Date
# 2014-01-02     19.754642
# 2014-01-03     19.320715
# 2014-01-06     19.426071
# 2014-01-07     19.287144
# 2014-01-08     19.409286
#                  ...
# 2023-12-22    193.600006
# 2023-12-26    193.050003
# 2023-12-27    193.149994
# 2023-12-28    193.580002
# 2023-12-29    192.529999
# Name: AAPL, Length: 2516, dtype: float64

# %%
# Normalise the data
close.AAPL.div(close.AAPL.iloc[0]).mul(100)
# Out:
# Date
# 2014-01-02    100.000000
# 2014-01-03     97.803415
# 2014-01-06     98.336739
# 2014-01-07     97.633474
# 2014-01-08     98.251773
#                  ...
# 2023-12-22    980.022829
# 2023-12-26    977.238658
# 2023-12-27    977.744821
# 2023-12-28    979.921565
# 2023-12-29    974.606343
# Name: AAPL, Length: 2516, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL     19.754642
# SPY     182.919998
# TSLA     10.006667
# Name: 2014-01-02 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#                   AAPL         SPY         TSLA
# Date
# 2014-01-02  100.000000  100.000000   100.000000
# 2014-01-03   97.803415   99.983600    99.640237
# 2014-01-06   98.336739   99.693857    97.934707
# 2014-01-07   97.633474  100.306143    99.506983
# 2014-01-08   98.251773  100.328016   100.786133
# ...                ...         ...          ...
# 2023-12-22  980.022829  258.938333  2523.717336
# 2023-12-26  977.238658  260.031707  2564.390139
# 2023-12-27  977.744821  260.501867  2612.658129
# 2023-12-28  979.921565  260.600266  2530.113066
# 2023-12-29  974.606343  259.845836  2483.144411
#
# [2516 rows x 3 columns]

# %%
norm_close = close.div(close.iloc[0]).mul(100)

# %%
norm_close.plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize=13)
plt.show()

# %%
aapl = close.AAPL.copy().to_frame() # Copy the AAPL column to a DataFrame
aapl
# Out:
#                   AAPL
# Date
# 2014-01-02   19.754642
# 2014-01-03   19.320715
# 2014-01-06   19.426071
# 2014-01-07   19.287144
# 2014-01-08   19.409286
# ...                ...
# 2023-12-22  193.600006
# 2023-12-26  193.050003
# 2023-12-27  193.149994
# 2023-12-28  193.580002
# 2023-12-29  192.529999
#
# [2516 rows x 1 columns]

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2014-01-02         NaN
# 2014-01-03   19.754642
# 2014-01-06   19.320715
# 2014-01-07   19.426071
# 2014-01-08   19.287144
# ...                ...
# 2023-12-22  194.679993
# 2023-12-26  193.600006
# 2023-12-27  193.050003
# 2023-12-28  193.149994
# 2023-12-29  193.580002
#
# [2516 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods=1)
aapl
# Out:
#                   AAPL        lag1
# Date
# 2014-01-02   19.754642         NaN
# 2014-01-03   19.320715   19.754642
# 2014-01-06   19.426071   19.320715
# 2014-01-07   19.287144   19.426071
# 2014-01-08   19.409286   19.287144
# ...                ...         ...
# 2023-12-22  193.600006  194.679993
# 2023-12-26  193.050003  193.600006
# 2023-12-27  193.149994  193.050003
# 2023-12-28  193.580002  193.149994
# 2023-12-29  192.529999  193.580002
#
# [2516 rows x 2 columns]

# %%
aapl["diff"] = aapl.AAPL.sub(aapl.lag1)
aapl
# Out:
#                   AAPL        lag1      diff
# Date
# 2014-01-02   19.754642         NaN       NaN
# 2014-01-03   19.320715   19.754642 -0.433928
# 2014-01-06   19.426071   19.320715  0.105356
# 2014-01-07   19.287144   19.426071 -0.138927
# 2014-01-08   19.409286   19.287144  0.122143
# ...                ...         ...       ...
# 2023-12-22  193.600006  194.679993 -1.079987
# 2023-12-26  193.050003  193.600006 -0.550003
# 2023-12-27  193.149994  193.050003  0.099991
# 2023-12-28  193.580002  193.149994  0.430008
# 2023-12-29  192.529999  193.580002 -1.050003
#
# [2516 rows x 3 columns]

# %%
aapl["% Change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
aapl
# Out:
#                   AAPL        lag1      diff  % Change     diff2  % Change2
# Date
# 2014-01-02   19.754642         NaN       NaN       NaN       NaN        NaN
# 2014-01-03   19.320715   19.754642 -0.433928 -2.196585 -0.433928  -2.196585
# 2014-01-06   19.426071   19.320715  0.105356  0.545302  0.105356   0.545302
# 2014-01-07   19.287144   19.426071 -0.138927 -0.715160 -0.138927  -0.715160
# 2014-01-08   19.409286   19.287144  0.122143  0.633286  0.122143   0.633286
# ...                ...         ...       ...       ...       ...        ...
# 2023-12-22  193.600006  194.679993 -1.079987 -0.554750 -1.079987  -0.554750
# 2023-12-26  193.050003  193.600006 -0.550003 -0.284092 -0.550003  -0.284092
# 2023-12-27  193.149994  193.050003  0.099991  0.051795  0.099991   0.051795
# 2023-12-28  193.580002  193.149994  0.430008  0.222629  0.430008   0.222629
# 2023-12-29  192.529999  193.580002 -1.050003 -0.542413 -1.050003  -0.542413
#
# [2516 rows x 6 columns]

# %%
aapl["diff2"] = aapl.AAPL.diff(periods=1)
aapl
# Out:
#                   AAPL        lag1      diff  % Change     diff2  % Change2
# Date
# 2014-01-02   19.754642         NaN       NaN       NaN       NaN        NaN
# 2014-01-03   19.320715   19.754642 -0.433928 -2.196585 -0.433928  -2.196585
# 2014-01-06   19.426071   19.320715  0.105356  0.545302  0.105356   0.545302
# 2014-01-07   19.287144   19.426071 -0.138927 -0.715160 -0.138927  -0.715160
# 2014-01-08   19.409286   19.287144  0.122143  0.633286  0.122143   0.633286
# ...                ...         ...       ...       ...       ...        ...
# 2023-12-22  193.600006  194.679993 -1.079987 -0.554750 -1.079987  -0.554750
# 2023-12-26  193.050003  193.600006 -0.550003 -0.284092 -0.550003  -0.284092
# 2023-12-27  193.149994  193.050003  0.099991  0.051795  0.099991   0.051795
# 2023-12-28  193.580002  193.149994  0.430008  0.222629  0.430008   0.222629
# 2023-12-29  192.529999  193.580002 -1.050003 -0.542413 -1.050003  -0.542413
#
# [2516 rows x 6 columns]

# %%
aapl["% Change2"] = aapl.AAPL.pct_change(periods=1).mul(100)
aapl
# Out:
#                   AAPL        lag1      diff  % Change     diff2  % Change2
# Date
# 2014-01-02   19.754642         NaN       NaN       NaN       NaN        NaN
# 2014-01-03   19.320715   19.754642 -0.433928 -2.196585 -0.433928  -2.196585
# 2014-01-06   19.426071   19.320715  0.105356  0.545302  0.105356   0.545302
# 2014-01-07   19.287144   19.426071 -0.138927 -0.715160 -0.138927  -0.715160
# 2014-01-08   19.409286   19.287144  0.122143  0.633286  0.122143   0.633286
# ...                ...         ...       ...       ...       ...        ...
# 2023-12-22  193.600006  194.679993 -1.079987 -0.554750 -1.079987  -0.554750
# 2023-12-26  193.050003  193.600006 -0.550003 -0.284092 -0.550003  -0.284092
# 2023-12-27  193.149994  193.050003  0.099991  0.051795  0.099991   0.051795
# 2023-12-28  193.580002  193.149994  0.430008  0.222629  0.430008   0.222629
# 2023-12-29  192.529999  193.580002 -1.050003 -0.542413 -1.050003  -0.542413
#
# [2516 rows x 6 columns]

# %%
del aapl["diff"]
del aapl["% Change"]
del aapl["lag1"]

aapl
# Out:
#                   AAPL  % Change2
# Date
# 2014-01-02   19.754642        NaN
# 2014-01-03   19.320715  -2.196585
# 2014-01-06   19.426071   0.545302
# 2014-01-07   19.287144  -0.715160
# 2014-01-08   19.409286   0.633286
# ...                ...        ...
# 2023-12-22  193.600006  -0.554750
# 2023-12-26  193.050003  -0.284092
# 2023-12-27  193.149994   0.051795
# 2023-12-28  193.580002   0.222629
# 2023-12-29  192.529999  -0.542413
#
# [2516 rows x 2 columns]

# %%
aapl.rename(columns={"% Change2": "Change"}, inplace=True)
aapl
# Out:
#                   AAPL    Change
# Date
# 2014-01-02   19.754642       NaN
# 2014-01-03   19.320715 -2.196585
# 2014-01-06   19.426071  0.545302
# 2014-01-07   19.287144 -0.715160
# 2014-01-08   19.409286  0.633286
# ...                ...       ...
# 2023-12-22  193.600006 -0.554750
# 2023-12-26  193.050003 -0.284092
# 2023-12-27  193.149994  0.051795
# 2023-12-28  193.580002  0.222629
# 2023-12-29  192.529999 -0.542413
#
# [2516 rows x 2 columns]

# %%
aapl.AAPL.resample("M").last()
# Out:
# /var/folders/_5/hcq3myc97jn9bf7mbp59_jn00000gn/T/ipykernel_19072/287408171.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   aapl.AAPL.resample("M").last()
# Date
# 2014-01-31     17.878571
# 2014-02-28     18.794287
# 2014-03-31     19.169287
# 2014-04-30     21.074642
# 2014-05-31     22.607143
#                  ...
# 2023-08-31    187.869995
# 2023-09-30    171.210007
# 2023-10-31    170.770004
# 2023-11-30    189.949997
# 2023-12-31    192.529999
# Freq: ME, Name: AAPL, Length: 120, dtype: float64

# %% [markdown]
# ## Calculating Monthly Change

# %%
aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# /var/folders/_5/hcq3myc97jn9bf7mbp59_jn00000gn/T/ipykernel_19072/2117523069.py:1: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Date
# 2014-01-31          NaN
# 2014-02-28     5.121865
# 2014-03-31     1.995287
# 2014-04-30     9.939626
# 2014-05-30     7.271778
#                 ...
# 2023-08-31    -4.367525
# 2023-09-29    -8.867828
# 2023-10-31    -0.256996
# 2023-11-30    11.231476
# 2023-12-29     1.358253
# Freq: BME, Name: AAPL, Length: 120, dtype: float64

# %%
 del aapl["Change"]
 aapl
# Out:
#                   AAPL
# Date
# 2014-01-02   19.754642
# 2014-01-03   19.320715
# 2014-01-06   19.426071
# 2014-01-07   19.287144
# 2014-01-08   19.409286
# ...                ...
# 2023-12-22  193.600006
# 2023-12-26  193.050003
# 2023-12-27  193.149994
# 2023-12-28  193.580002
# 2023-12-29  192.529999
#
# [2516 rows x 1 columns]

# %% [markdown]
# ## Calculate return mean variance standard deviation

# %%
ret = aapl.pct_change(periods=1).dropna()
ret
# Out:
#                 AAPL
# Date
# 2014-01-03 -0.021966
# 2014-01-06  0.005453
# 2014-01-07 -0.007152
# 2014-01-08  0.006333
# 2014-01-09 -0.012770
# ...              ...
# 2023-12-22 -0.005547
# 2023-12-26 -0.002841
# 2023-12-27  0.000518
# 2023-12-28  0.002226
# 2023-12-29 -0.005424
#
# [2515 rows x 1 columns]

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2515 entries, 2014-01-03 to 2023-12-29
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2515 non-null   float64
# dtypes: float64(1)
# memory usage: 39.3 KB

# %%
ret.plot(kind="hist", figsize=(12,8), bins=100, fontsize=13)
plt.show()

# %%
daily_mean_ret = ret.mean()
daily_mean_ret
# Out:
# AAPL    0.001066
# dtype: float64

# %%
daily_var = ret.var()
daily_var
# Out:
# AAPL    0.00032
# dtype: float64

# %%
daily_std = np.sqrt(daily_var)
daily_std
# Out:
# AAPL    0.017887
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.017887
# dtype: float64

# %%
annual_mean_ret = daily_mean_ret * 252
annual_mean_ret
# Out:
# AAPL    0.268561
# dtype: float64

# %%
annual_var = daily_var * 252
annual_var
# Out:
# AAPL    0.080625
# dtype: float64

# %%
annual_std = np.sqrt(annual_var)
annual_std
# Out:
# AAPL    0.283946
# dtype: float64

# %%
ret.std() * np.sqrt(252)
# Out:
# AAPL    0.283946
# dtype: float64

# %%
ticker = ["AAPL", "TSLA", "AMZN", "IBM", "MSFT", "NVDA"]

# %%
stocks = yf.download(ticker, start="2014-01-01", end="2024-01-01")
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
stocks
# Out:
# Price        Adj Close                                                  \
# Ticker            AAPL        AMZN         IBM        MSFT        NVDA
# Date
# 2014-01-02   17.296654   19.898500  115.518181   31.233070    3.740547
# 2014-01-03   16.916721   19.822001  116.209312   31.022932    3.695737
# 2014-01-06   17.008972   19.681499  115.810829   30.367338    3.745265
# 2014-01-07   16.887327   19.901501  118.120796   30.602684    3.806585
# 2014-01-08   16.994276   20.096001  117.037392   30.056355    3.858472
# ...                ...         ...         ...         ...         ...
# 2023-12-22  193.353287  153.419998  160.675140  373.888580  488.277069
# 2023-12-26  192.803986  153.410004  161.735489  373.968445  492.766907
# 2023-12-27  192.903839  153.339996  161.983231  373.379547  494.146820
# 2023-12-28  193.333298  153.380005  162.270599  374.587280  495.196777
# 2023-12-29  192.284637  151.940002  162.072403  375.345886  495.196777
#
# ...

# %%
close = stocks.loc[:, "Close"].copy()

normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize=13)
plt.show()

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
# Ticker          AAPL      AMZN       IBM      MSFT      NVDA      TSLA
# Date
# 2014-01-03 -0.021966 -0.003845  0.005983 -0.006728 -0.011980 -0.003598
# 2014-01-06  0.005453 -0.007088 -0.003429 -0.021132  0.013401 -0.017117
# 2014-01-07 -0.007152  0.011178  0.019946  0.007750  0.016373  0.016054
# 2014-01-08  0.006333  0.009773 -0.009172 -0.017852  0.013631  0.012855
# 2014-01-09 -0.012770 -0.002264 -0.003139 -0.006432 -0.037286 -0.024788

# %%
ret.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# Ticker
# AAPL    2515.0  0.001066  0.017887 -0.128647 -0.007272  0.000893  0.010151
# AMZN    2515.0  0.001026  0.020896 -0.140494 -0.008666  0.001084  0.011202
# IBM     2515.0  0.000077  0.014754 -0.128507 -0.006481  0.000389  0.007096
# MSFT    2515.0  0.001066  0.017063 -0.147390 -0.006916  0.000827  0.009797
# NVDA    2515.0  0.002343  0.029213 -0.187559 -0.011539  0.002200  0.016371
# TSLA    2515.0  0.001891  0.035063 -0.210628 -0.015330  0.001216  0.018764
#
#              max
# Ticker
# AAPL    0.119808
# AMZN    0.141311
# IBM     0.113010
# MSFT    0.142169
# NVDA    0.298067
# TSLA    0.198949

# %%
summary = ret.describe().T.loc[:, ["mean", "std"]]
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.001066  0.017887
# AMZN    0.001026  0.020896
# IBM     0.000077  0.014754
# MSFT    0.001066  0.017063
# NVDA    0.002343  0.029213
# TSLA    0.001891  0.035063

# %%
# Annualise the mean and standard deviation
summary["mean"] = summary["mean"] * 252
summary["std"] = summary["std"] * np.sqrt(252)
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.268561  0.283946
# AMZN    0.258624  0.331720
# IBM     0.019452  0.234213
# MSFT    0.268653  0.270872
# NVDA    0.590505  0.463749
# TSLA    0.476488  0.556610

# %%
summary.plot(kind="scatter", x="std", y="mean", figsize=(12,8), s=50, fontsize=15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "std"]+0.002, summary.loc[i, "mean"]+0.002), size=15)
    
plt.xlabel("Annualised Risk (Std. Deviation)", fontsize=15)
plt.ylabel("Annualised Return", fontsize=15)
plt.title("Risk/Return", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Risk/Return')

# %% [markdown]
# ## Correlartion and Covariance

# %%
ret.cov()
# Out:
# Ticker      AAPL      AMZN       IBM      MSFT      NVDA      TSLA
# Ticker
# AAPL    0.000320  0.000202  0.000108  0.000204  0.000289  0.000262
# AMZN    0.000202  0.000437  0.000089  0.000221  0.000307  0.000291
# IBM     0.000108  0.000089  0.000218  0.000114  0.000140  0.000112
# MSFT    0.000204  0.000221  0.000114  0.000291  0.000302  0.000242
# NVDA    0.000289  0.000307  0.000140  0.000302  0.000853  0.000429
# TSLA    0.000262  0.000291  0.000112  0.000242  0.000429  0.001229

# %%
ret.corr()
# Out:
# Ticker      AAPL      AMZN       IBM      MSFT      NVDA      TSLA
# Ticker
# AAPL    1.000000  0.541621  0.407792  0.669748  0.552381  0.417033
# AMZN    0.541621  1.000000  0.289622  0.620995  0.503218  0.397082
# IBM     0.407792  0.289622  1.000000  0.450886  0.324935  0.216320
# MSFT    0.669748  0.620995  0.450886  1.000000  0.605870  0.404425
# NVDA    0.552381  0.503218  0.324935  0.605870  1.000000  0.418873
# TSLA    0.417033  0.397082  0.216320  0.404425  0.418873  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap="Reds", annot=True, annot_kws={"size": 15}, vmax=0.6)
plt.show()

# %% [markdown]
# ## Simple returns and log returns

# %%
df = pd.DataFrame(index=[2016,2017,2018], data=[100,50,95], columns=["Price"])
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simple_returns = df.pct_change().dropna()
simple_returns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %% [markdown]
# mean returns can be misleading

# %%
simple_returns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
log_returns = np.log(df/df.shift(1)).dropna()
log_returns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
log_returns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %% [markdown]
# logreturns more accurate here

# %%
100*(np.exp(log_returns.mean()*2))
# Out:
# Price    95.0
# dtype: float64

# %% [markdown]
# # Moving Average

# %%
SPY = yf.download("SPY")
spy = SPY.Close.copy().to_frame()
spy
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-03-28  523.070007
# 2024-04-01  522.159973
# 2024-04-02  518.840027
# 2024-04-03  519.409973
# 2024-04-05  515.750000
#
# [7851 rows x 1 columns]

# %%
spy.plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize=13, loc="upper left")
plt.show()

# %%
spy_roll = spy.rolling(window=10).mean()
spy_roll.head(20)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875
# 1993-02-22  44.146875
# 1993-02-23  44.018750
# 1993-02-24  43.978125
# 1993-02-25  43.940625
# 1993-02-26  43.887500

# %%
spy.rolling(window=10).median()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-03-28  520.125000
# 2024-04-01  520.845001
# 2024-04-02  520.845001
# 2024-04-03  520.845001
# 2024-04-05  520.490021
#
# [7851 rows x 1 columns]

# %%
spy.rolling(window=10).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-03-28  523.169983
# 2024-04-01  523.169983
# 2024-04-02  523.169983
# 2024-04-03  523.169983
# 2024-04-05  523.169983
#
# [7851 rows x 1 columns]

# %%
spy.rolling(window=10, min_periods=5).max().head(20)
# Out:
#                Close
# Date
# 1993-01-29       NaN
# 1993-02-01       NaN
# 1993-02-02       NaN
# 1993-02-03       NaN
# 1993-02-04  45.00000
# 1993-02-05  45.00000
# 1993-02-08  45.00000
# 1993-02-09  45.00000
# 1993-02-10  45.00000
# 1993-02-11  45.00000
# 1993-02-12  45.00000
# 1993-02-16  45.00000
# 1993-02-17  45.00000
# 1993-02-18  45.00000
# 1993-02-19  44.96875
# 1993-02-22  44.96875
# 1993-02-23  44.93750
# 1993-02-24  44.93750
# 1993-02-25  44.93750
# 1993-02-26  44.59375

# %%
spy_roll.head(20)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875
# 1993-02-22  44.146875
# 1993-02-23  44.018750
# 1993-02-24  43.978125
# 1993-02-25  43.940625
# 1993-02-26  43.887500

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-03-28  523.070007
# 2024-04-01  522.159973
# 2024-04-02  518.840027
# 2024-04-03  519.409973
# 2024-04-05  515.750000
#
# [7851 rows x 1 columns]

# %%
spy["SMA50"] = spy.rolling(window=50, min_periods=50).mean()
spy
# Out:
#                  Close       SMA50
# Date
# 1993-01-29   43.937500         NaN
# 1993-02-01   44.250000         NaN
# 1993-02-02   44.343750         NaN
# 1993-02-03   44.812500         NaN
# 1993-02-04   45.000000         NaN
# ...                ...         ...
# 2024-03-28  523.070007  503.344601
# 2024-04-01  522.159973  504.258000
# 2024-04-02  518.840027  504.986201
# 2024-04-03  519.409973  505.705400
# 2024-04-05  515.750000  506.323201
#
# [7851 rows x 2 columns]

# %%
spy.plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize=13, loc="upper left")
plt.show()

# %%
spy["SMA200"] = spy.Close.rolling(window=200, min_periods=200).mean()
spy
# Out:
#                  Close       SMA50      SMA200
# Date
# 1993-01-29   43.937500         NaN         NaN
# 1993-02-01   44.250000         NaN         NaN
# 1993-02-02   44.343750         NaN         NaN
# 1993-02-03   44.812500         NaN         NaN
# 1993-02-04   45.000000         NaN         NaN
# ...                ...         ...         ...
# 2024-03-28  523.070007  503.344601  460.684901
# 2024-04-01  522.159973  504.258000  461.112401
# 2024-04-02  518.840027  504.986201  461.520701
# 2024-04-03  519.409973  505.705400  461.904751
# 2024-04-05  515.750000  506.323201  462.286201
#
# [7851 rows x 3 columns]

# %%
spy.plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize=13, loc="upper left")
plt.show()

# %%
spy["EMA100"] = spy.Close.ewm(span=100, min_periods=100).mean()
spy
# Out:
#                  Close       SMA50      SMA200      EMA100
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN
# 1993-02-01   44.250000         NaN         NaN         NaN
# 1993-02-02   44.343750         NaN         NaN         NaN
# 1993-02-03   44.812500         NaN         NaN         NaN
# 1993-02-04   45.000000         NaN         NaN         NaN
# ...                ...         ...         ...         ...
# 2024-03-28  523.070007  503.344601  460.684901  486.689697
# 2024-04-01  522.159973  504.258000  461.112401  487.392079
# 2024-04-02  518.840027  504.986201  461.520701  488.014810
# 2024-04-03  519.409973  505.705400  461.904751  488.636497
# 2024-04-05  515.750000  506.323201  462.286201  489.173398
#
# [7851 rows x 4 columns]

# %%
spy.plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize=13, loc="upper left")
plt.show()

# %%
spy["Day"] = spy.index.day_name()
spy
# Out:
#                  Close       SMA50      SMA200      EMA100        Day
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN     Friday
# 1993-02-01   44.250000         NaN         NaN         NaN     Monday
# 1993-02-02   44.343750         NaN         NaN         NaN    Tuesday
# 1993-02-03   44.812500         NaN         NaN         NaN  Wednesday
# 1993-02-04   45.000000         NaN         NaN         NaN   Thursday
# ...                ...         ...         ...         ...        ...
# 2024-03-28  523.070007  503.344601  460.684901  486.689697   Thursday
# 2024-04-01  522.159973  504.258000  461.112401  487.392079     Monday
# 2024-04-02  518.840027  504.986201  461.520701  488.014810    Tuesday
# 2024-04-03  519.409973  505.705400  461.904751  488.636497  Wednesday
# 2024-04-05  515.750000  506.323201  462.286201  489.173398     Friday
#
# [7851 rows x 5 columns]

# %%
spy["Quarter"] = spy.index.quarter
spy
# Out:
#                  Close       SMA50      SMA200      EMA100        Day  Quarter
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN     Friday        1
# 1993-02-01   44.250000         NaN         NaN         NaN     Monday        1
# 1993-02-02   44.343750         NaN         NaN         NaN    Tuesday        1
# 1993-02-03   44.812500         NaN         NaN         NaN  Wednesday        1
# 1993-02-04   45.000000         NaN         NaN         NaN   Thursday        1
# ...                ...         ...         ...         ...        ...      ...
# 2024-03-28  523.070007  503.344601  460.684901  486.689697   Thursday        1
# 2024-04-01  522.159973  504.258000  461.112401  487.392079     Monday        2
# 2024-04-02  518.840027  504.986201  461.520701  488.014810    Tuesday        2
# 2024-04-03  519.409973  505.705400  461.904751  488.636497  Wednesday        2
# 2024-04-05  515.750000  506.323201  462.286201  489.173398     Friday        2
#
# ...

# %% [markdown]
# ## RESET

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy = SPY.Close.copy().to_frame()
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-03-28  523.070007
# 2024-04-01  522.159973
# 2024-04-02  518.840027
# 2024-04-03  519.409973
# 2024-04-05  515.960022
#
# [7851 rows x 1 columns]

# %%
all_days = pd.date_range(start="2014-01-01", end="2024-01-01", freq="D")
all_days
# Out:
# DatetimeIndex(['2014-01-01', '2014-01-02', '2014-01-03', '2014-01-04',
#                '2014-01-05', '2014-01-06', '2014-01-07', '2014-01-08',
#                '2014-01-09', '2014-01-10',
#                ...
#                '2023-12-23', '2023-12-24', '2023-12-25', '2023-12-26',
#                '2023-12-27', '2023-12-28', '2023-12-29', '2023-12-30',
#                '2023-12-31', '2024-01-01'],
#               dtype='datetime64[ns]', length=3653, freq='D')

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-03-28  523.070007
# 2024-04-01  522.159973
# 2024-04-02  518.840027
# 2024-04-03  519.409973
# 2024-04-05  515.960022
#
# [7851 rows x 1 columns]

# %%
spy = spy.reindex(all_days)

# %%
spy
# Out:
#                  Close
# 2014-01-01         NaN
# 2014-01-02  182.919998
# 2014-01-03  182.889999
# 2014-01-04         NaN
# 2014-01-05         NaN
# ...                ...
# 2023-12-28  476.690002
# 2023-12-29  475.309998
# 2023-12-30         NaN
# 2023-12-31         NaN
# 2024-01-01         NaN
#
# [3653 rows x 1 columns]

# %%
spy.bfill()
# Out:
#                  Close
# 2014-01-01  182.919998
# 2014-01-02  182.919998
# 2014-01-03  182.889999
# 2014-01-04  182.360001
# 2014-01-05  182.360001
# ...                ...
# 2023-12-28  476.690002
# 2023-12-29  475.309998
# 2023-12-30         NaN
# 2023-12-31         NaN
# 2024-01-01         NaN
#
# [3653 rows x 1 columns]

# %%
SPY_weekly = yf.download("SPY", interval="1wk")
SPY_weekly
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   24.763741
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.344963
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.133615
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.552385
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   25.027925
# ...                ...         ...         ...         ...         ...
# 2024-03-04  512.030029  518.219971  504.910004  511.720001  510.134979
# 2024-03-11  510.480011  517.380005  508.119995  509.829987  508.250824
# 2024-03-18  514.000000  524.109985  511.119995  521.210022  521.210022
# 2024-03-25  519.799988  524.609985  518.400024  523.070007  523.070007
# 2024-04-01  523.830017  524.380005  514.010010  516.691711  516.691711
#
#                Volume
# Date
# ...

# %% [markdown]
# ## Cummulative Returns, Drawdowns etc.

# %%
apple = yf.download("AAPL")
apple = apple.Close.to_frame()
apple
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2024-04-01  170.029999
# 2024-04-02  168.839996
# 2024-04-03  169.649994
# 2024-04-04  168.820007
# 2024-04-05  169.479996
#
# [10919 rows x 1 columns]

# %%
apple["d_returns"] = np.log(apple.div(apple.shift(1)))
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.128348        NaN
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# ...                ...        ...
# 2024-04-01  170.029999  -0.008492
# 2024-04-02  168.839996  -0.007023
# 2024-04-03  169.649994   0.004786
# 2024-04-04  168.820007  -0.004904
# 2024-04-05  169.479996   0.003902
#
# [10919 rows x 2 columns]

# %%
apple.dropna(inplace=True)
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2024-04-01  170.029999  -0.008492
# 2024-04-02  168.839996  -0.007023
# 2024-04-03  169.649994   0.004786
# 2024-04-04  168.820007  -0.004904
# 2024-04-05  169.479996   0.003902
#
# [10918 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# 7.185744910068889

# %%
np.exp(apple.d_returns.sum())
# Out:
# 1320.472505273257

# %%
apple["cum_returns"] = apple.d_returns.cumsum().apply(np.exp)
apple
# Out:
#                  Close  d_returns  cum_returns
# Date
# 1980-12-15    0.121652  -0.053581     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261
# 1980-12-17    0.115513   0.024450     0.899998
# 1980-12-18    0.118862   0.028580     0.926092
# 1980-12-19    0.126116   0.059239     0.982610
# ...                ...        ...          ...
# 2024-04-01  170.029999  -0.008492  1324.757754
# 2024-04-02  168.839996  -0.007023  1315.486067
# 2024-04-03  169.649994   0.004786  1321.797015
# 2024-04-04  168.820007  -0.004904  1315.330326
# 2024-04-05  169.479996   0.003902  1320.472505
#
# [10918 rows x 3 columns]

# %%
apple.cum_returns.plot(figsize=(15,8), fontsize=13, title="AAPL Cumulative Returns")
plt.show()

# %%
apple.d_returns.mean()*252
# Out:
# 0.16585525896110645

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.4504875023679407

# %%
# how to calculate drawdowns
apple["cummax"]=apple.cum_returns.cummax()
apple
# Out:
#                  Close  d_returns  cum_returns       cummax
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829
# 1980-12-17    0.115513   0.024450     0.899998     0.947829
# 1980-12-18    0.118862   0.028580     0.926092     0.947829
# 1980-12-19    0.126116   0.059239     0.982610     0.982610
# ...                ...        ...          ...          ...
# 2024-04-01  170.029999  -0.008492  1324.757754  1543.537972
# 2024-04-02  168.839996  -0.007023  1315.486067  1543.537972
# 2024-04-03  169.649994   0.004786  1321.797015  1543.537972
# 2024-04-04  168.820007  -0.004904  1315.330326  1543.537972
# 2024-04-05  169.479996   0.003902  1320.472505  1543.537972
#
# [10918 rows x 4 columns]

# %%
apple[["cum_returns", "cummax"]].plot(figsize=(15,8), fontsize=13, title="AAPL Cumulative Returns + Cumulative Max")
plt.show()

# %%
apple["drawdown"] = apple["cummax"] - (apple["cum_returns"])
apple
# Out:
#                  Close  d_returns  cum_returns       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2024-04-01  170.029999  -0.008492  1324.757754  1543.537972  218.780218
# 2024-04-02  168.839996  -0.007023  1315.486067  1543.537972  228.051905
# 2024-04-03  169.649994   0.004786  1321.797015  1543.537972  221.740957
# 2024-04-04  168.820007  -0.004904  1315.330326  1543.537972  228.207646
# 2024-04-05  169.479996   0.003902  1320.472505  1543.537972  223.065466
#
# [10918 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 444.02718404402015

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index<="2023-01-05")]
# Out:
#                  Close  d_returns  cum_returns       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2022-12-29  129.610001   0.027931  1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993   0.002466  1012.325863  1418.097708  405.771845
# 2023-01-03  125.070000  -0.038122   974.460113  1418.097708  443.637594
# 2023-01-04  126.360001   0.010261   984.510920  1418.097708  433.586787
# 2023-01-05  125.019997  -0.010661   974.070524  1418.097708  444.027184
#
# [10605 rows x 5 columns]

# %%
apple["drawdown%"] = (apple["cummax"] - apple["cum_returns"]) / apple["cummax"]
apple
# Out:
#                  Close  d_returns  cum_returns       cummax    drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2024-04-01  170.029999  -0.008492  1324.757754  1543.537972  218.780218
# 2024-04-02  168.839996  -0.007023  1315.486067  1543.537972  228.051905
# 2024-04-03  169.649994   0.004786  1321.797015  1543.537972  221.740957
# 2024-04-04  168.820007  -0.004904  1315.330326  1543.537972  228.207646
# 2024-04-05  169.479996   0.003902  1320.472505  1543.537972  223.065466
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# ...

# %%
apple["drawdown%"].max()
# Out:
# 0.82216567924191

# %%
apple["drawdown%"].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index<="1997-12-23")]
# Out:
#                Close  d_returns  cum_returns    cummax  drawdown  drawdown%
# Date
# 1980-12-15  0.121652  -0.053581     0.947829  0.947829  0.000000   0.000000
# 1980-12-16  0.112723  -0.076231     0.878261  0.947829  0.069569   0.073398
# 1980-12-17  0.115513   0.024450     0.899998  0.947829  0.047831   0.050464
# 1980-12-18  0.118862   0.028580     0.926092  0.947829  0.021738   0.022934
# 1980-12-19  0.126116   0.059239     0.982610  0.982610  0.000000   0.000000
# ...              ...        ...          ...       ...       ...        ...
# 1997-12-17  0.124442  -0.026549     0.969567  5.060882  4.091315   0.808419
# 1997-12-18  0.123326  -0.009008     0.960872  5.060882  4.100010   0.810137
# 1997-12-19  0.122210  -0.009090     0.952177  5.060882  4.108705   0.811856
# 1997-12-22  0.118862  -0.027778     0.926092  5.060882  4.134790   0.817010
# 1997-12-23  0.115513  -0.028580     0.899998  5.060882  4.160883   0.822166
#
# [4306 rows x 6 columns]

# %% [markdown]
# # SMA Strategy

# %% [markdown]
# data = apple.Close.loc[()]

# %%
data = apple.Close.loc[(apple.index>="1997-12-23")].to_frame()
data
# Out:
#                  Close
# Date
# 1997-12-23    0.115513
# 1997-12-24    0.117188
# 1997-12-26    0.118862
# 1997-12-29    0.117188
# 1997-12-30    0.117746
# ...                ...
# 2024-04-01  170.029999
# 2024-04-02  168.839996
# 2024-04-03  169.649994
# 2024-04-04  168.820007
# 2024-04-05  169.479996
#
# [6613 rows x 1 columns]

# %%
sma_s = 50
sma_l = 100

# %%
data["sma_s"] = data.Close.rolling(window=sma_s).mean()
data["sma_l"] = data.Close.rolling(window=sma_l).mean()
data
# Out:
#                  Close       SMA50      SMA100  position  returns_buy_hold  \
# Date
# 1998-05-19    0.262277    0.247433    0.209372         1          0.030242
# 1998-05-20    0.263951    0.248415    0.210840         1          0.006362
# 1998-05-21    0.257813    0.248906    0.212229         1         -0.023529
# 1998-05-22    0.248884    0.249063    0.213546         1         -0.035248
# 1998-05-26    0.238281    0.248984    0.214752         1         -0.043536
# ...                ...         ...         ...       ...               ...
# 2024-04-01  170.029999  180.907199  185.231300        -1         -0.008492
# 2024-04-02  168.839996  180.452799  185.127400        -1         -0.007023
# 2024-04-03  169.649994  179.967999  185.005700        -1          0.004786
# 2024-04-04  168.820007  179.440800  184.865000        -1         -0.004904
# 2024-04-05  169.479996  178.940399  184.735700        -1          0.003902
#
#             strategy       sma_s     sma_l
# Date
# ...

# %%
data.plot(figsize=(15,8), fontsize=13, title="AAPL SMA{} | SMA{}".format(sma_s, sma_l))
# Out:
# <Axes: title={'center': 'AAPL SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2016"].plot(figsize=(15,8), fontsize=13, title="AAPL SMA{} | SMA{}".format(sma_s, sma_l))
# Out:
# <Axes: title={'center': 'AAPL SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)
data
# Out:
#                  Close       SMA50      SMA100  position  returns_buy_hold  \
# Date
# 1998-10-08    0.275112    0.332467    0.300463         1         -0.035858
# 1998-10-09    0.313616    0.332221    0.300977         1          0.130991
# 1998-10-12    0.334263    0.332723    0.301680         1          0.063759
# 1998-10-13    0.345982    0.333371    0.302561         1          0.034459
# 1998-10-14    0.333705    0.333940    0.303410         1         -0.036129
# ...                ...         ...         ...       ...               ...
# 2024-04-01  170.029999  180.907199  185.231300        -1         -0.008492
# 2024-04-02  168.839996  180.452799  185.127400        -1         -0.007023
# 2024-04-03  169.649994  179.967999  185.005700        -1          0.004786
# 2024-04-04  168.820007  179.440800  184.865000        -1         -0.004904
# 2024-04-05  169.479996  178.940399  184.735700        -1          0.003902
#
#             strategy       sma_s       sma_l
# Date
# ...

# %%
data["position"] = np.where(data["sma_s"]>data["sma_l"], 1, -1)
data
# Out:
#                  Close       SMA50      SMA100  position  returns_buy_hold  \
# Date
# 1998-10-08    0.275112    0.332467    0.300463         1         -0.035858
# 1998-10-09    0.313616    0.332221    0.300977         1          0.130991
# 1998-10-12    0.334263    0.332723    0.301680         1          0.063759
# 1998-10-13    0.345982    0.333371    0.302561         1          0.034459
# 1998-10-14    0.333705    0.333940    0.303410         1         -0.036129
# ...                ...         ...         ...       ...               ...
# 2024-04-01  170.029999  180.907199  185.231300        -1         -0.008492
# 2024-04-02  168.839996  180.452799  185.127400        -1         -0.007023
# 2024-04-03  169.649994  179.967999  185.005700        -1          0.004786
# 2024-04-04  168.820007  179.440800  184.865000        -1         -0.004904
# 2024-04-05  169.479996  178.940399  184.735700        -1          0.003902
#
#             strategy       sma_s       sma_l
# Date
# ...

# %%
data.loc["2016", ["sma_s", "sma_l", "position"]].plot(figsize=(15,8), fontsize=13, title="AAPL SMA{} | SMA{}".format(sma_s, sma_l), secondary_y="position")
# Out:
# <Axes: title={'center': 'AAPL SMA50 | SMA100'}, xlabel='Date'>

# %%
data["returns_buy_hold"] = np.log(data.Close.div(data.Close.shift(1)))
data
# Out:
#                  Close       SMA50      SMA100  position  returns_buy_hold  \
# Date
# 1998-10-08    0.275112    0.332467    0.300463         1               NaN
# 1998-10-09    0.313616    0.332221    0.300977         1          0.130991
# 1998-10-12    0.334263    0.332723    0.301680         1          0.063759
# 1998-10-13    0.345982    0.333371    0.302561         1          0.034459
# 1998-10-14    0.333705    0.333940    0.303410         1         -0.036129
# ...                ...         ...         ...       ...               ...
# 2024-04-01  170.029999  180.907199  185.231300        -1         -0.008492
# 2024-04-02  168.839996  180.452799  185.127400        -1         -0.007023
# 2024-04-03  169.649994  179.967999  185.005700        -1          0.004786
# 2024-04-04  168.820007  179.440800  184.865000        -1         -0.004904
# 2024-04-05  169.479996  178.940399  184.735700        -1          0.003902
#
#             strategy       sma_s       sma_l
# Date
# ...

# %%
data["strategy"] = data["returns_buy_hold"] * data["position"].shift(1)
data
# Out:
#                  Close       SMA50      SMA100  position  returns_buy_hold  \
# Date
# 1998-10-08    0.275112    0.332467    0.300463         1               NaN
# 1998-10-09    0.313616    0.332221    0.300977         1          0.130991
# 1998-10-12    0.334263    0.332723    0.301680         1          0.063759
# 1998-10-13    0.345982    0.333371    0.302561         1          0.034459
# 1998-10-14    0.333705    0.333940    0.303410         1         -0.036129
# ...                ...         ...         ...       ...               ...
# 2024-04-01  170.029999  180.907199  185.231300        -1         -0.008492
# 2024-04-02  168.839996  180.452799  185.127400        -1         -0.007023
# 2024-04-03  169.649994  179.967999  185.005700        -1          0.004786
# 2024-04-04  168.820007  179.440800  184.865000        -1         -0.004904
# 2024-04-05  169.479996  178.940399  184.735700        -1          0.003902
#
#             strategy       sma_s       sma_l
# Date
# ...

# %%
data.dropna(inplace=True)

# %%
data[["returns_buy_hold", "strategy"]].sum()
# Out:
# returns_buy_hold    6.423312
# strategy            2.248696
# dtype: float64

# %%
data[["returns_buy_hold", "strategy"]].sum().apply(np.exp) # what 1 USD investment will be
# Out:
# returns_buy_hold    616.039990
# strategy              9.475372
# dtype: float64

# %%
data[["returns_buy_hold", "strategy"]].std() * np.sqrt(252) # annualised risk/std
# Out:
# returns_buy_hold    0.416559
# strategy            0.416826
# dtype: float64

# %%
data.Close.plot(figsize=(15,8), fontsize=13)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Strategy adjusted with long bias

# %%
data["position2"] = np.where(data["sma_s"]>data["sma_l"], 1, 0)
data
# Out:
#                  Close       SMA50      SMA100  position  returns_buy_hold  \
# Date
# 1998-10-09    0.313616    0.332221    0.300977         1          0.130991
# 1998-10-12    0.334263    0.332723    0.301680         1          0.063759
# 1998-10-13    0.345982    0.333371    0.302561         1          0.034459
# 1998-10-14    0.333705    0.333940    0.303410         1         -0.036129
# 1998-10-15    0.327009    0.334051    0.304297         1         -0.020270
# ...                ...         ...         ...       ...               ...
# 2024-04-01  170.029999  180.907199  185.231300        -1         -0.008492
# 2024-04-02  168.839996  180.452799  185.127400        -1         -0.007023
# 2024-04-03  169.649994  179.967999  185.005700        -1          0.004786
# 2024-04-04  168.820007  179.440800  184.865000        -1         -0.004904
# 2024-04-05  169.479996  178.940399  184.735700        -1          0.003902
#
#             strategy       sma_s       sma_l  position2
# ...

# %%
data["strategy2"] = data["returns_buy_hold"] * data["position2"].shift(1)
data
# Out:
#                  Close       SMA50      SMA100  position  returns_buy_hold  \
# Date
# 1998-10-09    0.313616    0.332221    0.300977         1          0.130991
# 1998-10-12    0.334263    0.332723    0.301680         1          0.063759
# 1998-10-13    0.345982    0.333371    0.302561         1          0.034459
# 1998-10-14    0.333705    0.333940    0.303410         1         -0.036129
# 1998-10-15    0.327009    0.334051    0.304297         1         -0.020270
# ...                ...         ...         ...       ...               ...
# 2024-04-01  170.029999  180.907199  185.231300        -1         -0.008492
# 2024-04-02  168.839996  180.452799  185.127400        -1         -0.007023
# 2024-04-03  169.649994  179.967999  185.005700        -1          0.004786
# 2024-04-04  168.820007  179.440800  184.865000        -1         -0.004904
# 2024-04-05  169.479996  178.940399  184.735700        -1          0.003902
#
# ...

# %%
data.dropna(inplace=True)

# %%
data[["returns_buy_hold", "strategy2"]].sum()
# Out:
# returns_buy_hold    6.292321
# strategy2           4.205013
# dtype: float64

# %%
data[["returns_buy_hold", "strategy2"]].sum().apply(np.exp) # what 1 USD investment will be
# Out:
# returns_buy_hold    540.406075
# strategy2            67.021462
# dtype: float64

# %%
data[["returns_buy_hold", "strategy2"]].std() * np.sqrt(252) # annualised risk/std
# Out:
# returns_buy_hold    0.415794
# strategy2           0.340690
# dtype: float64

# %%
## Strategy 2 is better than strategy 1

data[["returns_buy_hold", "strategy", "strategy2"]].std() * np.sqrt(252) # annualised risk/std
# Out:
# returns_buy_hold    0.415794
# strategy            0.416053
# strategy2           0.340690
# dtype: float64

# %% [markdown]
# Creating a function

# %%
def test_strategy(stock, start, end, SMA):
    df = yf.download(stock, start=start, end=end)
    data = df.Close.to_frame()
    data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"] = data.Close.rolling(window=int(SMA[0])).mean()
    data["SMA_L"] = data.Close.rolling(window=int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    data["position"] = np.where(data["SMA_S"]>data["SMA_L"], 1, -1)
    data["strategy"] = data["returns"] * data["position"].shift(1)
    data.dropna(inplace=True)
    ret = np.exp(data["strategy"].sum())
    std = data["strategy"].std() * np.sqrt(252)
    return ret, std

# %%
test_strategy("TSLA", "2014-01-01", "2024-01-01", [50, 100])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (20.617844096292995, 0.5545340673476605)

# %% [markdown]
# Creating a class

# %%
class SMABacktester():
    def __init__(self, symbol, SMA_S, SMA_L, start, end):
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start
        self.end = end
        self.results = None
        self.get_data()
        
    def get_data(self):
        df = yf.download(self.symbol, self.start, self.end)
        data = df.Close.to_frame()
        data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"] = data.Close.rolling(window=int(self.SMA_S)).mean()
        data["SMA_L"] = data.Close.rolling(window=int(self.SMA_L)).mean()
        self.data2 = data
        
        return data
    
    def test_results(self):
        data = self.data2.copy().dropna()
        data["position"] = np.where(data["SMA_S"]>data["SMA_L"], 1, -1)
        data["strategy"] = data["returns"] * data["position"].shift(1)
        data.dropna(inplace=True)
        data["bhreturns"] = data["returns"].cumsum().apply(np.exp)
        data["strategyreturns"] = data["strategy"].cumsum().apply(np.exp)
        self.results = data
        perf = data["strategyreturns"].iloc[-1] # Get last row
        outperf = perf - data["bhreturns"].iloc[-1]
        return round(perf, 6), round(outperf, 6)
    
    def plot_results(self):
        if self.results is None:
            print("No results to plot. Run the test first pls! :)")
        else:
            title="{}| SMA_S={} | SMA_L{}".format(self.symbol,self.SMA_S, self.SMA_L)
            self.results[["bhreturns", "strategyreturns"]].plot(figsize=(15,8), fontsize=13, title=title)

# %%
tester= SMABacktester("SPY",50,100, "2000-01-01","2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (2.592726, 0.297824)

# %%
tester.plot_results()
